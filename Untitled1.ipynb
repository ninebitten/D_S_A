# %% [markdown]
# <a href="https://colab.research.google.com/github/ninebitten/D_S_A/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import cv2
import numpy as np
import requests

# %%
image = Image.open(requests.get('https://a57.foxnews.com/media.foxbusiness.com/BrightCove/854081161001/201805/2879/931/524/854081161001_5782482890001_5782477388001-vs.jpg', stream=True).raw)
image = image.resize((450,250))
image_arr = np.array(image)
image
# Out:
# <PIL.Image.Image image mode=RGB size=450x250 at 0x7F665A2F5990>

# %%
import cv2

# %%
grey = cv2.cvtColor(image_arr,cv2.COLOR_BGR2GRAY)
Image.fromarray(grey)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3a50fa1c35e7> in <cell line: 1>()
# ----> 1 grey = cv2.cvtColor(image_arr,cv2.COLOR_BGR2GRAY)
#       2 Image.fromarray(grey)
#
# NameError: name 'image_arr' is not defined

# %%
import os
from PIL import Image
import glob

# %%
grey = cv2.cvtColor(image_arr,cv2.COLOR_BGR2GRAY)
Image.fromarray(grey)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3a50fa1c35e7> in <cell line: 1>()
# ----> 1 grey = cv2.cvtColor(image_arr,cv2.COLOR_BGR2GRAY)
#       2 Image.fromarray(grey)
#
# NameError: name 'image_arr' is not defined

# %%
blur = cv2.GaussianBlur(grey,(5,5),0)
Image.fromarray(blur)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-0fc56979d15d> in <cell line: 1>()
# ----> 1 blur = cv2.GaussianBlur(grey,(5,5),0)
#       2 Image.fromarray(blur)
#
# NameError: name 'grey' is not defined
